# %%
import torch
import random
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageFile, Image

from FFHQ import FFHQ
from CelebDataset import CelebDataset
from MyModels import GeneratorModel, DiscriminatorModel
import imageio.v2 as imageio

# %%
#GPU Check

ngpu = 1
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(device,"is available!")
# Out:
# cuda:0 is available!

# %%
# DATA set check and load

transform = transforms.Compose([
                transforms.Resize(128),
                transforms.CenterCrop(128),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])
dataset = FFHQ('FFHQ', transform=transform)
dataloader = DataLoader(dataset, shuffle=True, batch_size=64, num_workers=0)

# %%
# view function and check the sample imgs

def view_samples(images):
    img = torchvision.utils.make_grid(images, padding=2, normalize=True)
    img = img.cpu().numpy()
    plt.figure(figsize = (8, 8))
    plt.imshow(np.transpose(img, (1,2,0)))
    plt.show()
    
test = iter(dataloader)
sample = next(test)
print(sample.size())
view_samples(sample)
# Out:
# torch.Size([64, 3, 128, 128])

# %%
# save the progress of learning result pics

def save_progress(images, epoch, step):
    img = torchvision.utils.make_grid(images, padding=2, normalize=True)
    img = img.cpu().numpy()
    img = np.transpose(img, (1,2,0))
    img = np.uint8(img*255)
    imageio.imwrite(f"progress_pics\PCA_LSGAN_FFHQ\{epoch}-{step}.jpg", img)

# %%
# save the model's state

def save_model_state(model, optimizer, loss, epoch, name):
    model_path = f"saved_models/{name}{epoch}.pt"
    state_dict = {
        'epoch' : epoch,
        'model_state_dict' : model.state_dict(),
        'opt_state_dict' : optimizer.state_dict(),
        'training_loss' : loss,
    }
    torch.save(state_dict, model_path)

# %%
# load the saved model

def load_model_state(model, filename):
    model_info = torch.load(f"saved_models/{filename}.pt")
    optimizer = torch.optim.Adam(model.parameters())
    optimizer.load_state_dict(model_info["opt_state_dict"])
    model.load_state_dict(model_info["model_state_dict"])
    return model, optimizer

# %%
# making loss graph function

def plot_losses(gen, dis):
    fig = plt.figure(figsize=(10, 5))
    ax = plt.subplot(111)
    ax.plot(gen, label="Generator")
    ax.plot(dis, label="Discriminator")
    plt.title("PCA_LSGAN Gen/Dis losses")
    ax.legend()
    plt.show()

# %%
# initialize step

n_z = 100 # 잠재공간 벡터 크기(생성자 입력값 크기)
n_c = 3 # 이미지 채널 갯수(RGB)
n_feature_maps_g = 64 # 생성자의 특징 맵 크기
n_feature_maps_d = 64 # 구분자의 특징 맵 크기
epochs = 10

fixed_noise = torch.randn(64, n_z, 1, 1).to(device)
torch.save(fixed_noise, "fixed_noise.pt")

# %%
noise = torch.randn(128, 1, 1, 1, device=device)

PCA_path = 'progress_pics\PCA_face_result128.jpg'
PCA_img = imageio.imread(PCA_path)

plt.imshow(PCA_img)


x_PCA_img = torch.tensor(PCA_img).to(device)
print(x_PCA_img.shape)
image = x_PCA_img.repeat(128,1,1,1).float()
print(image.shape)

test = noise * image
print(test.size())
# Out:
# torch.Size([128, 128])
# torch.Size([128, 1, 128, 128])
# torch.Size([128, 1, 128, 128])

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
        
class GeneratorModel(nn.Module):
    def __init__(self, n_z, n_fmps, n_c):
        super(GeneratorModel, self).__init__()
        self.net = nn.Sequential(
            nn.MaxPool2d(8),
            #64, 1, 16 16
            nn.Conv2d(1, 100, kernel_size=9 ,stride=8 ),
            #64 100 1 1
            nn.ConvTranspose2d(n_z, n_fmps*8, 4, 1, 0),
            nn.BatchNorm2d(n_fmps*8),
            nn.LeakyReLU(0.2, True),
            #64 512 4 4 
            nn.ConvTranspose2d(n_fmps*8, n_fmps*4, 4, 2, 1),
            nn.BatchNorm2d(n_fmps*4),
            nn.LeakyReLU(0.2, True),
            #64 256 8 8
            nn.ConvTranspose2d(n_fmps*4, n_fmps*2, 4, 2, 1),
            nn.BatchNorm2d(n_fmps*2),
            nn.LeakyReLU(0.2, True),
            # 64 128 16 16
            nn.ConvTranspose2d(n_fmps*2, n_fmps*1, 4, 2, 1),
            nn.BatchNorm2d(n_fmps*1),
            nn.LeakyReLU(0.2, True),
            # 64 64 32 32
            nn.ConvTranspose2d(n_fmps*1, 32, 4, 2, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, True),
            # 64 32 64 64 
            nn.ConvTranspose2d(32, n_c, 4, 2, 1),
            nn.Tanh()
            #64 3 128 128 
        )
        self.net.apply(weights_init)



    def forward(self, x):
        #print(x.shape)
        x = self.net(x)
        #print(x.shape)
        return x

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

class DiscriminatorModel(nn.Module):
    def __init__(self, n_c, n_fmps):
        super(DiscriminatorModel, self).__init__()

        self.net = nn.Sequential(
            nn.Conv2d(n_c, 32, 4, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, True),
            nn.Conv2d(32, n_fmps, 4, stride=2, padding=1),
            nn.BatchNorm2d(n_fmps),
            nn.LeakyReLU(0.2, True),
            nn.Conv2d(n_fmps, n_fmps*2, 4, stride=2, padding=1),
            nn.BatchNorm2d(n_fmps*2),
            nn.LeakyReLU(0.2, True),
            nn.Conv2d(n_fmps*2, n_fmps*4, 4, stride=2, padding=1),
            nn.BatchNorm2d(n_fmps*4),
            nn.LeakyReLU(0.2, True),
            nn.Conv2d(n_fmps*4, n_fmps*8, 4, stride=2, padding=1),
            nn.BatchNorm2d(n_fmps*8),
            nn.LeakyReLU(0.2, True),
            nn.Conv2d(n_fmps * 8, 1, 4, stride=1, padding=0),
            nn.Sigmoid()
        )
        self.linear = nn.Linear(1, 1)
        self.net.apply(weights_init)
        self.linear.apply(weights_init)
    def forward(self, x):
        x = self.net(x)
        #print(x.shape)
        x = self.linear(x)
        #print(x.shape)
        return x.view(-1, 1, 1, 1)

# %%
g_losses = [] # 생성자 loss
d_losses = [] # 구분자 loss

Dis = DiscriminatorModel(n_c, n_feature_maps_d).to(device) # 구분자 모델 생성
Gen = GeneratorModel(n_z, n_feature_maps_g, n_c).to(device) # 생성자 모델 생성

lr_g = 2e-4 # 생성자 learning rate 설정
lr_d = 2e-4 # 구분자 learning rate 설정
Dis_opt = optim.Adam(Dis.parameters(), lr=lr_d, betas=(0.5, 0.999)) # 구분자 옵티마이저 설정
Gen_opt = optim.Adam(Gen.parameters(), lr=lr_g, betas=(0.5, 0.999)) # 생성자 옵티마이저 설정
criterion = nn.MSELoss()

len(dataloader)
checkpoint = int(len(dataloader)/1094)

d_running_loss = 0.
g_running_loss = 0.

# %%
print(Dis)
print(checkpoint)
# Out:
# DiscriminatorModel(
#   (net): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.2, inplace=True)
#     (12): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.2, inplace=True)
#     (15): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1))
#     (16): Sigmoid()
#   )
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )
# 1

# %%
print(Gen)
# Out:
# GeneratorModel(
#   (net): Sequential(
#     (0): MaxPool2d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     (1): Conv2d(1, 100, kernel_size=(9, 9), stride=(8, 8))
#     (2): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1))
#     (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2, inplace=True)
#     (14): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (15): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.2, inplace=True)
#     (17): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (18): Tanh()
#   )
# )

# %%
# Training part

for e in range(1, epochs+1):
    print(f"Epoch {e} started.")
    for i, batch in enumerate(dataloader, 1):
        
        batch_size = batch.size(0)
        real_image = batch.to(device)

        fake_label = torch.zeros(batch_size, 1, 1, 1).to(device)
        real_label = torch.ones(batch_size, 1, 1, 1).to(device)

        Dis.zero_grad()
        D_x = Dis(real_image)
        D_x_loss = criterion(D_x, real_label)
        d_running_loss += D_x_loss.item()
        D_x_loss.backward()

        test_PCA = imageio.imread(f'progress_pics\PCA_FFHQ_result\PCA_FFHQ\pca_sample{i}.jpg')
        X_train_PCA = torch.tensor(test_PCA).to(device).repeat(batch_size,1,1,1).float()
        
        z = torch.randn(batch_size, 1, 1, 1).to(device)  
        #pca_noise batchsize,1,128,128
        pca_noise = X_train_PCA * z

        G_z = Gen(pca_noise)
        D_G_z = Dis(G_z.detach())
        D_G_z_loss = criterion(D_G_z, fake_label)
        d_running_loss += D_G_z_loss.item()
        D_G_z_loss.backward()
        
        Dis_opt.step()
        
        Gen.zero_grad()
        G_z = Gen(pca_noise)
        D_G_z = Dis(G_z)
        G_z_loss = criterion(D_G_z, real_label)
        g_running_loss += G_z_loss.item()
        
        G_z_loss.backward()    
        Gen_opt.step()
        
        if i % checkpoint == 0:
            
            g_current_loss = g_running_loss/checkpoint
            d_current_loss = d_running_loss/checkpoint
            g_losses.append(g_current_loss)
            d_losses.append(d_current_loss)
            print(f"[Generator loss: {g_current_loss}, Discriminator loss: {d_current_loss}]")

            if (i * checkpoint) % 10 == 0:
                fixed_z_images = Gen(test).detach()
                save_progress(fixed_z_images, e, i//checkpoint)
            
            g_running_loss = 0.
            d_running_loss = 0.
# Out:
# Epoch 1 started.
# [Generator loss: 0.8188773393630981, Discriminator loss: 0.6619897857308388]
# [Generator loss: 0.39285674691200256, Discriminator loss: 0.5274277031421661]
# [Generator loss: 0.38469502329826355, Discriminator loss: 0.5268617421388626]
# [Generator loss: 0.3853134214878082, Discriminator loss: 0.5278611183166504]
# [Generator loss: 0.3850391209125519, Discriminator loss: 0.5268068611621857]
# [Generator loss: 0.38290321826934814, Discriminator loss: 0.5273224711418152]
# [Generator loss: 0.38739562034606934, Discriminator loss: 0.5262676179409027]
# [Generator loss: 0.3889583945274353, Discriminator loss: 0.5262265652418137]
# [Generator loss: 0.385366827249527, Discriminator loss: 0.5266948938369751]
# [Generator loss: 0.3824630677700043, Discriminator loss: 0.5271064788103104]
# [Generator loss: 0.3824898302555084, Discriminator loss: 0.5270026624202728]
# [Generator loss: 0.38145577907562256, Discriminator loss: 0.5271198749542236]
# [Generator loss: 0.38179588317871094, Discriminator loss: 0.5267778635025024]
# [Generator loss: 0.3816792964935303, Discriminator loss: 0.5267426818609238]
# [Generator loss: 0.39470329880714417, Discriminator loss: 0.5256218910217285]
# [Generator loss: 0.38356995582580566, Discriminator loss: 0.5265370607376099]
# [Generator loss: 0.3860086500644684, Discriminator loss: 0.5265570133924484]
# [Generator loss: 0.37974873185157776, Discriminator loss: 0.5270131528377533]
# [Generator loss: 0.37924206256866455, Discriminator loss: 0.5267928242683411]
# [Generator loss: 0.3794372081756592, Discriminator loss: 0.526839554309845]
# [Generator loss: 0.37865203619003296, Discriminator loss: 0.5267708599567413]
# [Generator loss: 0.37889590859413147, Discriminator loss: 0.5265382528305054]
# [Generator loss: 0.3800848126411438, Discriminator loss: 0.5262993574142456]
# [Generator loss: 0.37810957431793213, Discriminator loss: 0.5265567600727081]
# [Generator loss: 0.37789610028266907, Discriminator loss: 0.526545912027359]
# [Generator loss: 0.37954044342041016, Discriminator loss: 0.5258197486400604]
# [Generator loss: 0.3782510459423065, Discriminator loss: 0.5261141210794449]
# [Generator loss: 0.3777497708797455, Discriminator loss: 0.5260889679193497]
# [Generator loss: 0.37724876403808594, Discriminator loss: 0.5262306183576584]
# [Generator loss: 0.37702471017837524, Discriminator loss: 0.5263634920120239]
# [Generator loss: 0.377315491437912, Discriminator loss: 0.5257505625486374]
# [Generator loss: 0.4184457063674927, Discriminator loss: 0.5245559513568878]
# [Generator loss: 0.3782276213169098, Discriminator loss: 0.5255139768123627]
# [Generator loss: 0.3761036694049835, Discriminator loss: 0.5257142782211304]
# [Generator loss: 0.37585803866386414, Discriminator loss: 0.5257351696491241]
# [Generator loss: 0.3756772577762604, Discriminator loss: 0.5261011570692062]
# [Generator loss: 0.3753274977207184, Discriminator loss: 0.5257376730442047]
# [Generator loss: 0.37506696581840515, Discriminator loss: 0.5256986767053604]
# [Generator loss: 0.3749487102031708, Discriminator loss: 0.5253710150718689]
# [Generator loss: 0.3747236132621765, Discriminator loss: 0.5252185463905334]
# [Generator loss: 0.37444019317626953, Discriminator loss: 0.5251026451587677]
# [Generator loss: 0.37420082092285156, Discriminator loss: 0.5298930406570435]
# [Generator loss: 0.37394461035728455, Discriminator loss: 0.5249779522418976]
# [Generator loss: 0.37373292446136475, Discriminator loss: 0.5248645395040512]
# [Generator loss: 0.37352800369262695, Discriminator loss: 0.5249932110309601]
# [Generator loss: 0.37332168221473694, Discriminator loss: 0.5248904824256897]
# [Generator loss: 0.37311792373657227, Discriminator loss: 0.5246321856975555]
# [Generator loss: 0.37300634384155273, Discriminator loss: 0.5244924277067184]
# [Generator loss: 0.3726428151130676, Discriminator loss: 0.5245254784822464]
# [Generator loss: 0.3724920451641083, Discriminator loss: 0.5243729501962662]
# [Generator loss: 0.3722209334373474, Discriminator loss: 0.5243229269981384]
# [Generator loss: 0.3721187710762024, Discriminator loss: 0.5241810381412506]
# [Generator loss: 0.37188202142715454, Discriminator loss: 0.5241153836250305]
# [Generator loss: 0.3716129958629608, Discriminator loss: 0.5240764021873474]
# [Generator loss: 0.3713814914226532, Discriminator loss: 0.5240086913108826]
# [Generator loss: 0.37117743492126465, Discriminator loss: 0.5239357799291611]
# [Generator loss: 0.3709486126899719, Discriminator loss: 0.5238501280546188]
# [Generator loss: 0.3707720637321472, Discriminator loss: 0.523744210600853]
# [Generator loss: 0.37056130170822144, Discriminator loss: 0.5236744433641434]
# [Generator loss: 0.3703727722167969, Discriminator loss: 0.5235893130302429]
# [Generator loss: 0.3701701760292053, Discriminator loss: 0.52349753677845]
# [Generator loss: 0.37139976024627686, Discriminator loss: 0.5234267264604568]
# [Generator loss: 0.36991411447525024, Discriminator loss: 0.5233205109834671]
# [Generator loss: 0.3695163130760193, Discriminator loss: 0.5232795625925064]
# [Generator loss: 0.3695785105228424, Discriminator loss: 0.5231265425682068]
# [Generator loss: 0.3692171573638916, Discriminator loss: 0.5231119096279144]
# [Generator loss: 0.36898934841156006, Discriminator loss: 0.523028165102005]
# [Generator loss: 0.36880096793174744, Discriminator loss: 0.5229690968990326]
# [Generator loss: 0.36852821707725525, Discriminator loss: 0.5228862464427948]
# [Generator loss: 0.37671732902526855, Discriminator loss: 0.5222148895263672]
# [Generator loss: 0.3679746389389038, Discriminator loss: 0.522770568728447]
# [Generator loss: 0.36773237586021423, Discriminator loss: 0.5226992964744568]
# [Generator loss: 0.3674880862236023, Discriminator loss: 0.5226427614688873]
# [Generator loss: 0.3672623932361603, Discriminator loss: 0.5225596576929092]
# [Generator loss: 0.36705178022384644, Discriminator loss: 0.5224833935499191]
# [Generator loss: 0.36684226989746094, Discriminator loss: 0.52243572473526]
# [Generator loss: 0.36664342880249023, Discriminator loss: 0.5223247110843658]
# [Generator loss: 0.36642467975616455, Discriminator loss: 0.5222531706094742]
# [Generator loss: 0.3663603663444519, Discriminator loss: 0.5221077799797058]
# [Generator loss: 0.36597955226898193, Discriminator loss: 0.522112637758255]
# [Generator loss: 0.36578068137168884, Discriminator loss: 0.5220479667186737]
# [Generator loss: 0.3655809164047241, Discriminator loss: 0.5219495743513107]
# [Generator loss: 0.3653414249420166, Discriminator loss: 0.52189040184021]
# [Generator loss: 0.3651297092437744, Discriminator loss: 0.5218042880296707]
# [Generator loss: 0.3649291396141052, Discriminator loss: 0.5217341482639313]
# [Generator loss: 0.3647327423095703, Discriminator loss: 0.5216443538665771]
# [Generator loss: 0.36450618505477905, Discriminator loss: 0.5215788930654526]
# [Generator loss: 0.3643004298210144, Discriminator loss: 0.5214976370334625]
# [Generator loss: 0.36408108472824097, Discriminator loss: 0.5214287340641022]
# [Generator loss: 0.3638611435890198, Discriminator loss: 0.5213572978973389]
# [Generator loss: 0.36364567279815674, Discriminator loss: 0.5213110893964767]
# [Generator loss: 0.36342567205429077, Discriminator loss: 0.5212344825267792]
# [Generator loss: 0.3633139431476593, Discriminator loss: 0.5211069285869598]
# [Generator loss: 0.3631565570831299, Discriminator loss: 0.521005392074585]
# [Generator loss: 0.36284464597702026, Discriminator loss: 0.5209777057170868]
# [Generator loss: 0.3626108467578888, Discriminator loss: 0.5209228545427322]
# [Generator loss: 0.36260664463043213, Discriminator loss: 0.5207873582839966]
# [Generator loss: 0.362370103597641, Discriminator loss: 0.5207447707653046]
# [Generator loss: 0.362022340297699, Discriminator loss: 0.520688459277153]
# [Generator loss: 0.3617481291294098, Discriminator loss: 0.5206449627876282]
# [Generator loss: 0.36228156089782715, Discriminator loss: 0.520379975438118]
# [Generator loss: 0.36156636476516724, Discriminator loss: 0.5204235017299652]
# [Generator loss: 0.36146050691604614, Discriminator loss: 0.5203497111797333]
# [Generator loss: 0.3609541654586792, Discriminator loss: 0.5203413963317871]
# [Generator loss: 0.36091676354408264, Discriminator loss: 0.5202213674783707]
# [Generator loss: 0.3606559634208679, Discriminator loss: 0.5201883465051651]
# [Generator loss: 0.36090102791786194, Discriminator loss: 0.5200144350528717]
# [Generator loss: 0.36048102378845215, Discriminator loss: 0.519975334405899]
# [Generator loss: 0.36046457290649414, Discriminator loss: 0.5199135839939117]
# [Generator loss: 0.3612514138221741, Discriminator loss: 0.5196971148252487]
# [Generator loss: 0.3595927953720093, Discriminator loss: 0.5198888778686523]
# [Generator loss: 0.35926416516304016, Discriminator loss: 0.5198036730289459]
# [Generator loss: 0.3589978814125061, Discriminator loss: 0.5197486579418182]
# [Generator loss: 0.35892748832702637, Discriminator loss: 0.5195966958999634]
# [Generator loss: 0.3585885167121887, Discriminator loss: 0.5196056813001633]
# [Generator loss: 0.3583934009075165, Discriminator loss: 0.5195126831531525]
# [Generator loss: 0.3582402467727661, Discriminator loss: 0.5194217264652252]
# [Generator loss: 0.3579612374305725, Discriminator loss: 0.5193846225738525]
# [Generator loss: 0.35775673389434814, Discriminator loss: 0.5193149149417877]
# [Generator loss: 0.3575518727302551, Discriminator loss: 0.5192438811063766]
# [Generator loss: 0.3573910593986511, Discriminator loss: 0.5191876143217087]
# [Generator loss: 0.35722866654396057, Discriminator loss: 0.5190743952989578]
# [Generator loss: 0.35694390535354614, Discriminator loss: 0.5190708339214325]
# [Generator loss: 0.356768935918808, Discriminator loss: 0.5189586579799652]
# [Generator loss: 0.3568307161331177, Discriminator loss: 0.5187816023826599]
# [Generator loss: 0.35638272762298584, Discriminator loss: 0.5188310593366623]
# [Generator loss: 0.3561567962169647, Discriminator loss: 0.5187545269727707]
# [Generator loss: 0.3558923602104187, Discriminator loss: 0.5187159776687622]
# [Generator loss: 0.35571765899658203, Discriminator loss: 0.5186523646116257]
# [Generator loss: 0.3555673658847809, Discriminator loss: 0.5185885429382324]
# [Generator loss: 0.3554493188858032, Discriminator loss: 0.5184578150510788]
# [Generator loss: 0.35512804985046387, Discriminator loss: 0.5184195190668106]
# [Generator loss: 0.35488414764404297, Discriminator loss: 0.5183739513158798]
# [Generator loss: 0.35484445095062256, Discriminator loss: 0.5182504951953888]
# [Generator loss: 0.35521480441093445, Discriminator loss: 0.5180785357952118]
# [Generator loss: 0.3547225594520569, Discriminator loss: 0.518079936504364]
# [Generator loss: 0.3542463779449463, Discriminator loss: 0.5180850028991699]
# [Generator loss: 0.3556620478630066, Discriminator loss: 0.517805203795433]
# [Generator loss: 0.3538764417171478, Discriminator loss: 0.5179661214351654]
# [Generator loss: 0.3534768521785736, Discriminator loss: 0.5179387032985687]
# [Generator loss: 0.3532997965812683, Discriminator loss: 0.517867848277092]
# [Generator loss: 0.3530430197715759, Discriminator loss: 0.5178722888231277]
# [Generator loss: 0.3528186082839966, Discriminator loss: 0.5177340507507324]
# [Generator loss: 0.35263293981552124, Discriminator loss: 0.5176745355129242]
# [Generator loss: 0.3524969816207886, Discriminator loss: 0.5175754129886627]
# [Generator loss: 0.352228045463562, Discriminator loss: 0.5175394415855408]
# [Generator loss: 0.3520941138267517, Discriminator loss: 0.5174558907747269]
# [Generator loss: 0.35184246301651, Discriminator loss: 0.5173980593681335]
# [Generator loss: 0.3516060709953308, Discriminator loss: 0.517347663640976]
# [Generator loss: 0.3514699935913086, Discriminator loss: 0.5172941982746124]
# [Generator loss: 0.351406455039978, Discriminator loss: 0.5171841681003571]
# [Generator loss: 0.3510073125362396, Discriminator loss: 0.5171601176261902]
# [Generator loss: 0.3511255085468292, Discriminator loss: 0.5169918239116669]
# [Generator loss: 0.3507179617881775, Discriminator loss: 0.5170046538114548]
# [Generator loss: 0.3510945439338684, Discriminator loss: 0.5167585015296936]
# [Generator loss: 0.3503909707069397, Discriminator loss: 0.5168708264827728]
# [Generator loss: 0.3501725494861603, Discriminator loss: 0.5168075859546661]
# [Generator loss: 0.34984612464904785, Discriminator loss: 0.5169161856174469]
# [Generator loss: 0.3496910631656647, Discriminator loss: 0.5166980922222137]
# [Generator loss: 0.34952133893966675, Discriminator loss: 0.5166151374578476]
# [Generator loss: 0.3494150638580322, Discriminator loss: 0.516521766781807]
# [Generator loss: 0.3493439257144928, Discriminator loss: 0.5164779722690582]
# [Generator loss: 0.348956823348999, Discriminator loss: 0.516442283987999]
# [Generator loss: 0.34967729449272156, Discriminator loss: 0.516269326210022]
# [Generator loss: 0.3491607904434204, Discriminator loss: 0.5162457823753357]
# [Generator loss: 0.34855279326438904, Discriminator loss: 0.516352042555809]
# [Generator loss: 0.34827935695648193, Discriminator loss: 0.5161410570144653]
# [Generator loss: 0.34785208106040955, Discriminator loss: 0.5161612182855606]
# [Generator loss: 0.34764984250068665, Discriminator loss: 0.5161287188529968]
# [Generator loss: 0.34744566679000854, Discriminator loss: 0.5160459876060486]
# [Generator loss: 0.3473007380962372, Discriminator loss: 0.5159648656845093]
# [Generator loss: 0.3471769094467163, Discriminator loss: 0.5158986449241638]
# [Generator loss: 0.3469362258911133, Discriminator loss: 0.5158361345529556]
# [Generator loss: 0.3467021584510803, Discriminator loss: 0.5159047245979309]
# [Generator loss: 0.34660542011260986, Discriminator loss: 0.5156995803117752]
# [Generator loss: 0.3463670015335083, Discriminator loss: 0.515707477927208]
# [Generator loss: 0.3463192880153656, Discriminator loss: 0.5156669020652771]
# [Generator loss: 0.3476272225379944, Discriminator loss: 0.5153251886367798]
# [Generator loss: 0.34582215547561646, Discriminator loss: 0.5155166685581207]
# [Generator loss: 0.3455822169780731, Discriminator loss: 0.5154376924037933]
# [Generator loss: 0.34541890025138855, Discriminator loss: 0.5153751820325851]
# [Generator loss: 0.3451596796512604, Discriminator loss: 0.5153816342353821]
# [Generator loss: 0.3449457883834839, Discriminator loss: 0.5152579545974731]
# [Generator loss: 0.34477970004081726, Discriminator loss: 0.5152535140514374]
# [Generator loss: 0.34470105171203613, Discriminator loss: 0.515141099691391]
# [Generator loss: 0.3459782004356384, Discriminator loss: 0.515132874250412]
# [Generator loss: 0.344163179397583, Discriminator loss: 0.5150475651025772]
# [Generator loss: 0.3457212448120117, Discriminator loss: 0.514780804514885]
# [Generator loss: 0.34376657009124756, Discriminator loss: 0.5149464160203934]
# [Generator loss: 0.3435436487197876, Discriminator loss: 0.5149383246898651]
# [Generator loss: 0.34335729479789734, Discriminator loss: 0.5148464441299438]
# [Generator loss: 0.34316152334213257, Discriminator loss: 0.514784425497055]
# [Generator loss: 0.3429853022098541, Discriminator loss: 0.5147518962621689]
# [Generator loss: 0.3429274559020996, Discriminator loss: 0.5146129131317139]
# [Generator loss: 0.3430182933807373, Discriminator loss: 0.5144583582878113]
# [Generator loss: 0.3424684703350067, Discriminator loss: 0.5145496428012848]
# [Generator loss: 0.34220075607299805, Discriminator loss: 0.5145227015018463]
# [Generator loss: 0.34205567836761475, Discriminator loss: 0.5144198834896088]
# [Generator loss: 0.3418503403663635, Discriminator loss: 0.5144393742084503]
# [Generator loss: 0.3416273593902588, Discriminator loss: 0.5144361853599548]
# [Generator loss: 0.3424415588378906, Discriminator loss: 0.5140770971775055]
# [Generator loss: 0.341307669878006, Discriminator loss: 0.5142453610897064]
# [Generator loss: 0.3412311375141144, Discriminator loss: 0.5142672508955002]
# [Generator loss: 0.34092092514038086, Discriminator loss: 0.5141048729419708]
# [Generator loss: 0.3407113254070282, Discriminator loss: 0.5140631198883057]
# [Generator loss: 0.34048545360565186, Discriminator loss: 0.5140439420938492]
# [Generator loss: 0.3403824269771576, Discriminator loss: 0.5139297842979431]
# [Generator loss: 0.34077632427215576, Discriminator loss: 0.5137489140033722]
# [Generator loss: 0.3400398790836334, Discriminator loss: 0.5138398557901382]
# [Generator loss: 0.3399319052696228, Discriminator loss: 0.5137562453746796]
# [Generator loss: 0.339600145816803, Discriminator loss: 0.5137375295162201]
# [Generator loss: 0.3395368158817291, Discriminator loss: 0.5136705636978149]
# [Generator loss: 0.3396211862564087, Discriminator loss: 0.5135418772697449]
# [Generator loss: 0.3395402431488037, Discriminator loss: 0.5135396718978882]
# [Generator loss: 0.3417662978172302, Discriminator loss: 0.5133391916751862]
# [Generator loss: 0.3386889100074768, Discriminator loss: 0.5136090815067291]
# [Generator loss: 0.3385899066925049, Discriminator loss: 0.5133471488952637]
# [Generator loss: 0.3385494351387024, Discriminator loss: 0.5132540464401245]
# [Generator loss: 0.3380984365940094, Discriminator loss: 0.5133131295442581]
# [Generator loss: 0.3378845453262329, Discriminator loss: 0.5132787823677063]
# [Generator loss: 0.33769136667251587, Discriminator loss: 0.5132365226745605]
# [Generator loss: 0.3376449644565582, Discriminator loss: 0.5131193399429321]
# [Generator loss: 0.33736085891723633, Discriminator loss: 0.5131018161773682]
# [Generator loss: 0.3372006416320801, Discriminator loss: 0.5130470097064972]
# [Generator loss: 0.3370208740234375, Discriminator loss: 0.5129873603582382]
# [Generator loss: 0.33679381012916565, Discriminator loss: 0.512973815202713]
# [Generator loss: 0.3366081118583679, Discriminator loss: 0.5129088461399078]
# [Generator loss: 0.3364183306694031, Discriminator loss: 0.5128900408744812]
# [Generator loss: 0.3362298607826233, Discriminator loss: 0.5128697007894516]
# [Generator loss: 0.3360520005226135, Discriminator loss: 0.512772411108017]
# [Generator loss: 0.3358820080757141, Discriminator loss: 0.512698769569397]
# [Generator loss: 0.335673987865448, Discriminator loss: 0.5126519203186035]
# [Generator loss: 0.3354872167110443, Discriminator loss: 0.512641191482544]
# [Generator loss: 0.33536073565483093, Discriminator loss: 0.5125275999307632]
# [Generator loss: 0.3362446129322052, Discriminator loss: 0.5122781544923782]
# [Generator loss: 0.3349669277667999, Discriminator loss: 0.5124808102846146]
# [Generator loss: 0.3347795009613037, Discriminator loss: 0.5123980045318604]
# [Generator loss: 0.3345978260040283, Discriminator loss: 0.5124872028827667]
# [Generator loss: 0.3344235420227051, Discriminator loss: 0.5123358219861984]
# [Generator loss: 0.33428019285202026, Discriminator loss: 0.512254923582077]
# [Generator loss: 0.33404386043548584, Discriminator loss: 0.5122505873441696]
# [Generator loss: 0.33387792110443115, Discriminator loss: 0.5121583342552185]
# [Generator loss: 0.33370718359947205, Discriminator loss: 0.5121010094881058]
# [Generator loss: 0.33352431654930115, Discriminator loss: 0.5120548754930496]
# [Generator loss: 0.33332714438438416, Discriminator loss: 0.5120353251695633]
# [Generator loss: 0.3331889510154724, Discriminator loss: 0.5119366943836212]
# [Generator loss: 0.3329729437828064, Discriminator loss: 0.5119207948446274]
# [Generator loss: 0.3328697681427002, Discriminator loss: 0.5118816792964935]
# [Generator loss: 0.3329930007457733, Discriminator loss: 0.5117246806621552]
# [Generator loss: 0.3325379490852356, Discriminator loss: 0.5117374658584595]
# [Generator loss: 0.3323269486427307, Discriminator loss: 0.5117053985595703]
# [Generator loss: 0.43697816133499146, Discriminator loss: 0.5110006779432297]
# [Generator loss: 0.8735208511352539, Discriminator loss: 0.5073188245296478]
# [Generator loss: 1.0388445854187012, Discriminator loss: 0.4494937136769295]
# [Generator loss: 0.9590312242507935, Discriminator loss: 0.43828529119491577]
# [Generator loss: 1.1974684000015259, Discriminator loss: 0.41627931594848633]
# [Generator loss: 0.9855524301528931, Discriminator loss: 0.4335397332906723]
# [Generator loss: 0.9682172536849976, Discriminator loss: 0.43495558202266693]
# [Generator loss: 0.8288944363594055, Discriminator loss: 0.4525822773575783]
# [Generator loss: 0.8824338912963867, Discriminator loss: 0.443963885307312]
# [Generator loss: 1.008302927017212, Discriminator loss: 0.4414408877491951]
# [Generator loss: 1.0348494052886963, Discriminator loss: 0.42913178354501724]
# [Generator loss: 0.9732174873352051, Discriminator loss: 0.43240513652563095]
# [Generator loss: 0.958529531955719, Discriminator loss: 0.43290936946868896]
# [Generator loss: 1.067232370376587, Discriminator loss: 0.4266151264309883]
# [Generator loss: 0.8966817855834961, Discriminator loss: 0.43567363917827606]
# [Generator loss: 0.9030527472496033, Discriminator loss: 0.44214145839214325]
# [Generator loss: 0.8219509124755859, Discriminator loss: 0.44571584463119507]
# [Generator loss: 0.8919227123260498, Discriminator loss: 0.43765541166067123]
# [Generator loss: 0.948647141456604, Discriminator loss: 0.4274555519223213]
# [Generator loss: 1.0149459838867188, Discriminator loss: 0.4269099682569504]
# [Generator loss: 0.9825224876403809, Discriminator loss: 0.4219689518213272]
# [Generator loss: 1.01142156124115, Discriminator loss: 0.41367296129465103]
# [Generator loss: 0.6240471601486206, Discriminator loss: 0.46107544004917145]
# [Generator loss: 0.5984044075012207, Discriminator loss: 0.4876575767993927]
# [Generator loss: 0.6540626287460327, Discriminator loss: 0.4845726191997528]
# [Generator loss: 0.7001403570175171, Discriminator loss: 0.47275039553642273]
# [Generator loss: 0.6081029772758484, Discriminator loss: 0.48456987738609314]
# [Generator loss: 0.6152099967002869, Discriminator loss: 0.49653759598731995]
# [Generator loss: 0.5922059416770935, Discriminator loss: 0.4904193580150604]
# [Generator loss: 0.5975543260574341, Discriminator loss: 0.4798930883407593]
# [Generator loss: 0.6345220804214478, Discriminator loss: 0.4806438982486725]
# [Generator loss: 0.46213144063949585, Discriminator loss: 0.4999299943447113]
# [Generator loss: 0.4530637860298157, Discriminator loss: 0.48748743534088135]
# [Generator loss: 0.338835746049881, Discriminator loss: 0.506769135594368]
# [Generator loss: 0.33942627906799316, Discriminator loss: 0.5073187947273254]
# [Generator loss: 0.32065221667289734, Discriminator loss: 0.5083831250667572]
# [Generator loss: 0.3201543092727661, Discriminator loss: 0.5082626193761826]
# [Generator loss: 0.3223682641983032, Discriminator loss: 0.508446455001831]
# [Generator loss: 0.3191224932670593, Discriminator loss: 0.5087061375379562]
# [Generator loss: 0.32986605167388916, Discriminator loss: 0.5074234455823898]
# [Generator loss: 0.31906962394714355, Discriminator loss: 0.5088827610015869]
# [Generator loss: 0.31938448548316956, Discriminator loss: 0.5082987248897552]
# [Generator loss: 0.3217241168022156, Discriminator loss: 0.5079574435949326]
# [Generator loss: 0.318173348903656, Discriminator loss: 0.5082546919584274]
# [Generator loss: 0.3193763494491577, Discriminator loss: 0.5079089105129242]
# [Generator loss: 0.3224395513534546, Discriminator loss: 0.5078497231006622]
# [Generator loss: 0.3181481957435608, Discriminator loss: 0.5081548392772675]
# [Generator loss: 0.3195047974586487, Discriminator loss: 0.5093626081943512]
# [Generator loss: 0.3280123770236969, Discriminator loss: 0.5073238909244537]
# [Generator loss: 0.3194420039653778, Discriminator loss: 0.5079090297222137]
# [Generator loss: 0.31745877861976624, Discriminator loss: 0.5080105513334274]
# [Generator loss: 0.3172663152217865, Discriminator loss: 0.5081861615180969]
# [Generator loss: 0.31731078028678894, Discriminator loss: 0.50800821185112]
# [Generator loss: 0.3174809217453003, Discriminator loss: 0.5077501535415649]
# [Generator loss: 0.33843597769737244, Discriminator loss: 0.5063965171575546]
# [Generator loss: 0.3167567849159241, Discriminator loss: 0.5080289244651794]
# [Generator loss: 0.3165498375892639, Discriminator loss: 0.5090536028146744]
# [Generator loss: 0.3164363503456116, Discriminator loss: 0.5079091787338257]
# [Generator loss: 0.316364586353302, Discriminator loss: 0.5077693462371826]
# [Generator loss: 0.3163182735443115, Discriminator loss: 0.507762685418129]
# [Generator loss: 0.316009521484375, Discriminator loss: 0.5079501867294312]
# [Generator loss: 0.31592410802841187, Discriminator loss: 0.5079261064529419]
# [Generator loss: 0.3157734274864197, Discriminator loss: 0.5077914446592331]
# [Generator loss: 0.31565654277801514, Discriminator loss: 0.5076729655265808]
# [Generator loss: 0.3167056441307068, Discriminator loss: 0.5072860717773438]
# [Generator loss: 0.31786954402923584, Discriminator loss: 0.507335975766182]
# [Generator loss: 0.31594395637512207, Discriminator loss: 0.50759556889534]
# [Generator loss: 0.363000750541687, Discriminator loss: 0.506414383649826]
# [Generator loss: 0.3150211274623871, Discriminator loss: 0.5076168477535248]
# [Generator loss: 0.3148956298828125, Discriminator loss: 0.5078195482492447]
# [Generator loss: 0.3147960901260376, Discriminator loss: 0.5077536106109619]
# [Generator loss: 0.31468063592910767, Discriminator loss: 0.5074529945850372]
# [Generator loss: 0.314536988735199, Discriminator loss: 0.5076118111610413]
# [Generator loss: 0.3144006133079529, Discriminator loss: 0.507430911064148]
# [Generator loss: 0.31427881121635437, Discriminator loss: 0.50739586353302]
# [Generator loss: 0.31416335701942444, Discriminator loss: 0.5074436664581299]
# [Generator loss: 0.3140564560890198, Discriminator loss: 0.5073478668928146]
# [Generator loss: 0.3139129877090454, Discriminator loss: 0.5073344707489014]
# [Generator loss: 0.313815176486969, Discriminator loss: 0.507282480597496]
# [Generator loss: 0.31369107961654663, Discriminator loss: 0.5072486251592636]
# [Generator loss: 0.31357699632644653, Discriminator loss: 0.5072245299816132]
# [Generator loss: 0.3134256601333618, Discriminator loss: 0.5072136521339417]
# [Generator loss: 0.313304603099823, Discriminator loss: 0.5072671473026276]
# [Generator loss: 0.31323570013046265, Discriminator loss: 0.507141500711441]
# [Generator loss: 0.3130608797073364, Discriminator loss: 0.5071494877338409]
# [Generator loss: 0.31322038173675537, Discriminator loss: 0.5069579929113388]
# [Generator loss: 0.31299853324890137, Discriminator loss: 0.507004588842392]
# [Generator loss: 0.3128896951675415, Discriminator loss: 0.5069552212953568]
# [Generator loss: 0.31287217140197754, Discriminator loss: 0.5068988353013992]
# [Generator loss: 0.31258296966552734, Discriminator loss: 0.5069469809532166]
# [Generator loss: 0.3123469650745392, Discriminator loss: 0.5072711408138275]
# [Generator loss: 0.31221717596054077, Discriminator loss: 0.5072342157363892]
# [Generator loss: 0.3121483325958252, Discriminator loss: 0.5068755447864532]
# [Generator loss: 0.3120013475418091, Discriminator loss: 0.5069251358509064]
# [Generator loss: 0.31187117099761963, Discriminator loss: 0.5068511068820953]
# [Generator loss: 0.31173038482666016, Discriminator loss: 0.5068538188934326]
# [Generator loss: 0.31161069869995117, Discriminator loss: 0.5068144202232361]
# [Generator loss: 0.3114975094795227, Discriminator loss: 0.5068016350269318]
# [Generator loss: 0.3113778829574585, Discriminator loss: 0.5070713013410568]
# [Generator loss: 0.3113042712211609, Discriminator loss: 0.5067006945610046]
# [Generator loss: 0.3111304044723511, Discriminator loss: 0.5067190527915955]
# [Generator loss: 0.31102123856544495, Discriminator loss: 0.5066843181848526]
# [Generator loss: 0.3109174966812134, Discriminator loss: 0.5066421031951904]
# [Generator loss: 0.31087690591812134, Discriminator loss: 0.5065668821334839]
# [Generator loss: 0.3106992840766907, Discriminator loss: 0.5066591948270798]
# [Generator loss: 0.3106030225753784, Discriminator loss: 0.5065722912549973]
# [Generator loss: 0.31045618653297424, Discriminator loss: 0.5065371990203857]
# [Generator loss: 0.3106342554092407, Discriminator loss: 0.5063634663820267]
# [Generator loss: 0.3103339672088623, Discriminator loss: 0.506466805934906]
# [Generator loss: 0.3100643754005432, Discriminator loss: 0.5064823180437088]
# [Generator loss: 0.30999284982681274, Discriminator loss: 0.506428986787796]
# [Generator loss: 0.31009751558303833, Discriminator loss: 0.506355881690979]
# [Generator loss: 0.30971914529800415, Discriminator loss: 0.5065672099590302]
# [Generator loss: 0.3096209466457367, Discriminator loss: 0.5063796639442444]
# [Generator loss: 0.3095054030418396, Discriminator loss: 0.5063524842262268]
# [Generator loss: 0.30938059091567993, Discriminator loss: 0.5063161551952362]
# [Generator loss: 0.3095704913139343, Discriminator loss: 0.5061619877815247]
# [Generator loss: 0.30922025442123413, Discriminator loss: 0.5064363479614258]
# [Generator loss: 0.3091464638710022, Discriminator loss: 0.5061917155981064]
# [Generator loss: 0.3089466989040375, Discriminator loss: 0.5062262564897537]
# [Generator loss: 0.30970484018325806, Discriminator loss: 0.5060002952814102]
# [Generator loss: 0.30915966629981995, Discriminator loss: 0.50606769323349]
# [Generator loss: 0.30857551097869873, Discriminator loss: 0.5061685740947723]
# [Generator loss: 0.3084377646446228, Discriminator loss: 0.5061858594417572]
# [Generator loss: 0.3083726763725281, Discriminator loss: 0.5061022192239761]
# [Generator loss: 0.30818039178848267, Discriminator loss: 0.5061390995979309]
# [Generator loss: 0.30805644392967224, Discriminator loss: 0.506100207567215]
# [Generator loss: 0.3079555332660675, Discriminator loss: 0.5060777366161346]
# [Generator loss: 0.3078605532646179, Discriminator loss: 0.5060219168663025]
# [Generator loss: 0.3080333471298218, Discriminator loss: 0.5058934241533279]
# [Generator loss: 0.3075973689556122, Discriminator loss: 0.5060169696807861]
# [Generator loss: 0.3074725270271301, Discriminator loss: 0.5060171037912369]
# [Generator loss: 0.3074776530265808, Discriminator loss: 0.5058928728103638]
# [Generator loss: 0.3072931170463562, Discriminator loss: 0.5058921277523041]
# [Generator loss: 0.30715212225914, Discriminator loss: 0.5059226453304291]
# [Generator loss: 0.307077020406723, Discriminator loss: 0.5058618634939194]
# [Generator loss: 0.3069078028202057, Discriminator loss: 0.5059943497180939]
# [Generator loss: 0.3068310618400574, Discriminator loss: 0.5057967901229858]
# [Generator loss: 0.3072887063026428, Discriminator loss: 0.5056456923484802]
# [Generator loss: 0.30656713247299194, Discriminator loss: 0.5058268904685974]
# [Generator loss: 0.3065682053565979, Discriminator loss: 0.5059521794319153]
# [Generator loss: 0.3063516914844513, Discriminator loss: 0.5058131366968155]
# [Generator loss: 0.30622148513793945, Discriminator loss: 0.5057092010974884]
# [Generator loss: 0.30608463287353516, Discriminator loss: 0.5057197660207748]
# [Generator loss: 0.30673184990882874, Discriminator loss: 0.50547194480896]
# [Generator loss: 0.3058716654777527, Discriminator loss: 0.5056522190570831]
# [Generator loss: 0.30582401156425476, Discriminator loss: 0.505600243806839]
# [Generator loss: 0.3057056963443756, Discriminator loss: 0.5056185275316238]
# [Generator loss: 0.305544376373291, Discriminator loss: 0.50556680560112]
# [Generator loss: 0.3054751753807068, Discriminator loss: 0.5055584907531738]
# [Generator loss: 0.3053646981716156, Discriminator loss: 0.5055163502693176]
# [Generator loss: 0.3081268072128296, Discriminator loss: 0.5052135586738586]
# [Generator loss: 0.3050997853279114, Discriminator loss: 0.505482092499733]
# [Generator loss: 0.3056721091270447, Discriminator loss: 0.5053917169570923]
# [Generator loss: 0.3372018039226532, Discriminator loss: 0.5049313902854919]
# [Generator loss: 0.9063024520874023, Discriminator loss: 0.3758336156606674]
# [Generator loss: 0.7356932163238525, Discriminator loss: 0.4407491683959961]
# [Generator loss: 0.769423246383667, Discriminator loss: 0.4368240386247635]
# [Generator loss: 0.7588266730308533, Discriminator loss: 0.46409669518470764]
# [Generator loss: 0.8973875641822815, Discriminator loss: 0.4413682073354721]
# [Generator loss: 0.8935645818710327, Discriminator loss: 0.4199277013540268]
# [Generator loss: 0.9256548285484314, Discriminator loss: 0.4219548627734184]
# [Generator loss: 0.745886504650116, Discriminator loss: 0.4345056563615799]
# [Generator loss: 0.8724316954612732, Discriminator loss: 0.4516157954931259]
# [Generator loss: 0.7750008702278137, Discriminator loss: 0.4502539485692978]
# [Generator loss: 0.6784256100654602, Discriminator loss: 0.47135141491889954]
# [Generator loss: 0.7470004558563232, Discriminator loss: 0.4447205662727356]
# [Generator loss: 0.8522014617919922, Discriminator loss: 0.45712991058826447]
# [Generator loss: 0.6413906812667847, Discriminator loss: 0.4585794508457184]
# [Generator loss: 0.4312114715576172, Discriminator loss: 0.4899137318134308]
# [Generator loss: 0.6010380983352661, Discriminator loss: 0.4855891764163971]
# [Generator loss: 0.6338149905204773, Discriminator loss: 0.48658356070518494]
# [Generator loss: 0.46757248044013977, Discriminator loss: 0.48557814955711365]
# [Generator loss: 0.2994360327720642, Discriminator loss: 0.5044935792684555]
# [Generator loss: 0.29926586151123047, Discriminator loss: 0.5044714063405991]
# [Generator loss: 0.29916441440582275, Discriminator loss: 0.5045541226863861]
# [Generator loss: 0.2990840673446655, Discriminator loss: 0.504425048828125]
# [Generator loss: 0.2989500164985657, Discriminator loss: 0.5044339150190353]
# [Generator loss: 0.29885101318359375, Discriminator loss: 0.504399448633194]
# [Generator loss: 0.2987504005432129, Discriminator loss: 0.5044035911560059]
# [Generator loss: 0.2986517548561096, Discriminator loss: 0.5043547451496124]
# [Generator loss: 0.298552930355072, Discriminator loss: 0.5044630169868469]
# [Generator loss: 0.29845356941223145, Discriminator loss: 0.5043180733919144]
# [Generator loss: 0.29835644364356995, Discriminator loss: 0.504349559545517]
# [Generator loss: 0.2982568144798279, Discriminator loss: 0.5042837560176849]
# [Generator loss: 0.29815909266471863, Discriminator loss: 0.504264771938324]
# [Generator loss: 0.2980825901031494, Discriminator loss: 0.5042248368263245]
# [Generator loss: 0.2979632616043091, Discriminator loss: 0.5042421519756317]
# [Generator loss: 0.29786521196365356, Discriminator loss: 0.5042103677988052]
# [Generator loss: 0.2977682650089264, Discriminator loss: 0.5042107552289963]
# [Generator loss: 0.2976700961589813, Discriminator loss: 0.5041869878768921]
# [Generator loss: 0.2975720465183258, Discriminator loss: 0.5042017996311188]
# [Generator loss: 0.29747429490089417, Discriminator loss: 0.5041442811489105]
# [Generator loss: 0.29737669229507446, Discriminator loss: 0.5041414648294449]
# [Generator loss: 0.2972792387008667, Discriminator loss: 0.5041092336177826]
# [Generator loss: 0.2971830368041992, Discriminator loss: 0.504097506403923]
# [Generator loss: 0.2970963716506958, Discriminator loss: 0.5040744990110397]
# [Generator loss: 0.2969888746738434, Discriminator loss: 0.5040604472160339]
# [Generator loss: 0.29689109325408936, Discriminator loss: 0.5040452927350998]
# [Generator loss: 0.2967950105667114, Discriminator loss: 0.5040334761142731]
# [Generator loss: 0.29669761657714844, Discriminator loss: 0.50405153632164]
# [Generator loss: 0.29660093784332275, Discriminator loss: 0.5039989650249481]
# [Generator loss: 0.29650431871414185, Discriminator loss: 0.5040120184421539]
# [Generator loss: 0.29641443490982056, Discriminator loss: 0.504041314125061]
# [Generator loss: 0.29631179571151733, Discriminator loss: 0.5039499402046204]
# [Generator loss: 0.2962154746055603, Discriminator loss: 0.5039577782154083]
# [Generator loss: 0.29612061381340027, Discriminator loss: 0.5039325654506683]
# [Generator loss: 0.29602372646331787, Discriminator loss: 0.5039101541042328]
# [Generator loss: 0.29592740535736084, Discriminator loss: 0.5038884282112122]
# [Generator loss: 0.29583290219306946, Discriminator loss: 0.5038740038871765]
# [Generator loss: 0.2957422137260437, Discriminator loss: 0.5038565695285797]
# [Generator loss: 0.29564327001571655, Discriminator loss: 0.5038428902626038]
# [Generator loss: 0.2955454885959625, Discriminator loss: 0.5038434565067291]
# [Generator loss: 0.29544979333877563, Discriminator loss: 0.5038112103939056]
# [Generator loss: 0.29535403847694397, Discriminator loss: 0.5038473606109619]
# [Generator loss: 0.29530712962150574, Discriminator loss: 0.5037691593170166]
# [Generator loss: 0.29516375064849854, Discriminator loss: 0.5037746131420135]
# [Generator loss: 0.2950686812400818, Discriminator loss: 0.5038483440876007]
# [Generator loss: 0.294973760843277, Discriminator loss: 0.5038062930107117]
# [Generator loss: 0.29487913846969604, Discriminator loss: 0.5037213563919067]
# [Generator loss: 0.2947843670845032, Discriminator loss: 0.5037355422973633]
# [Generator loss: 0.294689804315567, Discriminator loss: 0.5036926567554474]
# [Generator loss: 0.2945953607559204, Discriminator loss: 0.5037454962730408]
# [Generator loss: 0.29450324177742004, Discriminator loss: 0.5036572366952896]
# [Generator loss: 0.2944067120552063, Discriminator loss: 0.5036560595035553]
# [Generator loss: 0.2943125367164612, Discriminator loss: 0.5036284625530243]
# [Generator loss: 0.29421889781951904, Discriminator loss: 0.5036270171403885]
# [Generator loss: 0.2941248118877411, Discriminator loss: 0.5036119818687439]
# [Generator loss: 0.29403063654899597, Discriminator loss: 0.5038072168827057]
# [Generator loss: 0.2939371168613434, Discriminator loss: 0.503571629524231]
# [Generator loss: 0.29384344816207886, Discriminator loss: 0.5035690069198608]
# [Generator loss: 0.29375016689300537, Discriminator loss: 0.5035571157932281]
# [Generator loss: 0.2936564087867737, Discriminator loss: 0.5035360604524612]
# [Generator loss: 0.2935631275177002, Discriminator loss: 0.5035227388143539]
# [Generator loss: 0.2934698462486267, Discriminator loss: 0.503497838973999]
# [Generator loss: 0.2933768630027771, Discriminator loss: 0.50349161028862]
# [Generator loss: 0.2932840585708618, Discriminator loss: 0.5034693777561188]
# [Generator loss: 0.2931913733482361, Discriminator loss: 0.5034564286470413]
# [Generator loss: 0.2930983901023865, Discriminator loss: 0.5034427642822266]
# [Generator loss: 0.29300743341445923, Discriminator loss: 0.5034340023994446]
# [Generator loss: 0.2929132580757141, Discriminator loss: 0.5034116357564926]
# [Generator loss: 0.2928207814693451, Discriminator loss: 0.5034059286117554]
# [Generator loss: 0.2927289307117462, Discriminator loss: 0.5033892542123795]
# [Generator loss: 0.2926369309425354, Discriminator loss: 0.5034039318561554]
# [Generator loss: 0.2925443947315216, Discriminator loss: 0.5033587515354156]
# [Generator loss: 0.292452335357666, Discriminator loss: 0.503343790769577]
# [Generator loss: 0.2923605740070343, Discriminator loss: 0.5033441185951233]
# [Generator loss: 0.2922701835632324, Discriminator loss: 0.5033157169818878]
# [Generator loss: 0.2921772599220276, Discriminator loss: 0.5033024549484253]
# [Generator loss: 0.2920856475830078, Discriminator loss: 0.5032863318920135]
# [Generator loss: 0.29199445247650146, Discriminator loss: 0.5032851845026016]
# [Generator loss: 0.29190316796302795, Discriminator loss: 0.5032735615968704]
# [Generator loss: 0.29181215167045593, Discriminator loss: 0.5032505691051483]
# [Generator loss: 0.29172074794769287, Discriminator loss: 0.5032323002815247]
# [Generator loss: 0.29162997007369995, Discriminator loss: 0.5032463818788528]
# [Generator loss: 0.2915385365486145, Discriminator loss: 0.503210037946701]
# [Generator loss: 0.2914479374885559, Discriminator loss: 0.5031965672969818]
# [Generator loss: 0.29135727882385254, Discriminator loss: 0.5031790435314178]
# [Generator loss: 0.29126667976379395, Discriminator loss: 0.5031716823577881]
# [Generator loss: 0.29117637872695923, Discriminator loss: 0.5031527578830719]
# [Generator loss: 0.29108601808547974, Discriminator loss: 0.503138542175293]
# [Generator loss: 0.2909957766532898, Discriminator loss: 0.5032169073820114]
# [Generator loss: 0.2909061312675476, Discriminator loss: 0.503265380859375]
# [Generator loss: 0.29081547260284424, Discriminator loss: 0.5031066983938217]
# [Generator loss: 0.2907255291938782, Discriminator loss: 0.503087967634201]
# [Generator loss: 0.2906358242034912, Discriminator loss: 0.5030725002288818]
# [Generator loss: 0.2905464172363281, Discriminator loss: 0.5030595064163208]
# [Generator loss: 0.290456622838974, Discriminator loss: 0.5030466616153717]
# [Generator loss: 0.2903677523136139, Discriminator loss: 0.5030326098203659]
# [Generator loss: 0.290277898311615, Discriminator loss: 0.5030205547809601]
# [Generator loss: 0.290188729763031, Discriminator loss: 0.5030082017183304]
# [Generator loss: 0.2900997996330261, Discriminator loss: 0.5029949396848679]
# [Generator loss: 0.29001158475875854, Discriminator loss: 0.5030127167701721]
# [Generator loss: 0.2899218201637268, Discriminator loss: 0.5029703080654144]
# [Generator loss: 0.2898331582546234, Discriminator loss: 0.5029593706130981]
# [Generator loss: 0.2897454500198364, Discriminator loss: 0.5029451847076416]
# [Generator loss: 0.28965628147125244, Discriminator loss: 0.5029309988021851]
# [Generator loss: 0.2895675599575043, Discriminator loss: 0.5029315948486328]
# [Generator loss: 0.2894793748855591, Discriminator loss: 0.5029056668281555]
# [Generator loss: 0.28939133882522583, Discriminator loss: 0.5029060989618301]
# [Generator loss: 0.2893054485321045, Discriminator loss: 0.5028793662786484]
# [Generator loss: 0.2892150580883026, Discriminator loss: 0.5028683841228485]
# [Generator loss: 0.28912726044654846, Discriminator loss: 0.502855971455574]
# [Generator loss: 0.2890395522117615, Discriminator loss: 0.5028440207242966]
# [Generator loss: 0.2889522910118103, Discriminator loss: 0.5028320848941803]
# [Generator loss: 0.28886473178863525, Discriminator loss: 0.5028203278779984]
# [Generator loss: 0.288777232170105, Discriminator loss: 0.5028074234724045]
# [Generator loss: 0.28869009017944336, Discriminator loss: 0.50279501080513]
# [Generator loss: 0.2886028289794922, Discriminator loss: 0.5027885437011719]
# [Generator loss: 0.2885158360004425, Discriminator loss: 0.5027711689472198]
# [Generator loss: 0.28842881321907043, Discriminator loss: 0.5027585476636887]
# [Generator loss: 0.28834205865859985, Discriminator loss: 0.502776175737381]
# [Generator loss: 0.2882553040981293, Discriminator loss: 0.5027347058057785]
# [Generator loss: 0.28816890716552734, Discriminator loss: 0.5027228891849518]
# [Generator loss: 0.28808265924453735, Discriminator loss: 0.5027124285697937]
# [Generator loss: 0.2879960834980011, Discriminator loss: 0.5027003884315491]
# [Generator loss: 0.28790992498397827, Discriminator loss: 0.5026875287294388]
# [Generator loss: 0.2878239154815674, Discriminator loss: 0.5026786625385284]
# [Generator loss: 0.2877376675605774, Discriminator loss: 0.502663791179657]
# [Generator loss: 0.28765201568603516, Discriminator loss: 0.5026538372039795]
# [Generator loss: 0.2875661849975586, Discriminator loss: 0.5026412010192871]
# [Generator loss: 0.28749746084213257, Discriminator loss: 0.5026150792837143]
# [Generator loss: 0.28739506006240845, Discriminator loss: 0.5026181638240814]
# [Generator loss: 0.28731024265289307, Discriminator loss: 0.5026051700115204]
# [Generator loss: 0.2872243821620941, Discriminator loss: 0.5025939643383026]
# [Generator loss: 0.2871392071247101, Discriminator loss: 0.5025841891765594]
# [Generator loss: 0.2870541512966156, Discriminator loss: 0.502571314573288]
# [Generator loss: 0.28696930408477783, Discriminator loss: 0.5025614202022552]
# [Generator loss: 0.286884605884552, Discriminator loss: 0.5025481283664703]
# [Generator loss: 0.2867995500564575, Discriminator loss: 0.5025374889373779]
# [Generator loss: 0.2867150604724884, Discriminator loss: 0.5025260895490646]
# [Generator loss: 0.2866307199001312, Discriminator loss: 0.5025284886360168]
# [Generator loss: 0.2865464687347412, Discriminator loss: 0.5025047957897186]
# [Generator loss: 0.28646212816238403, Discriminator loss: 0.5024929940700531]
# [Generator loss: 0.28637799620628357, Discriminator loss: 0.5024832338094711]
# [Generator loss: 0.2862943410873413, Discriminator loss: 0.5024700313806534]
# [Generator loss: 0.28621092438697815, Discriminator loss: 0.5024605691432953]
# [Generator loss: 0.28612643480300903, Discriminator loss: 0.5024484992027283]
# [Generator loss: 0.2860427498817444, Discriminator loss: 0.5024395883083344]
# [Generator loss: 0.2859593629837036, Discriminator loss: 0.5024263262748718]
# [Generator loss: 0.2858758568763733, Discriminator loss: 0.5024193525314331]
# [Generator loss: 0.2857925295829773, Discriminator loss: 0.5024057030677795]
# [Generator loss: 0.2857101857662201, Discriminator loss: 0.5023941993713379]
# [Generator loss: 0.28562626242637634, Discriminator loss: 0.502386212348938]
# [Generator loss: 0.28554341197013855, Discriminator loss: 0.502383828163147]
# [Generator loss: 0.2854606509208679, Discriminator loss: 0.5023675262928009]
# [Generator loss: 0.2853778600692749, Discriminator loss: 0.5023527294397354]
# [Generator loss: 0.28529560565948486, Discriminator loss: 0.5023408681154251]
# [Generator loss: 0.28521275520324707, Discriminator loss: 0.5023302137851715]
# [Generator loss: 0.2851305603981018, Discriminator loss: 0.5023282021284103]
# [Generator loss: 0.2850484549999237, Discriminator loss: 0.5023105442523956]
# [Generator loss: 0.284966379404068, Discriminator loss: 0.5022984594106674]
# [Generator loss: 0.28488433361053467, Discriminator loss: 0.502305805683136]
# [Generator loss: 0.28480249643325806, Discriminator loss: 0.5022782683372498]
# [Generator loss: 0.28472089767456055, Discriminator loss: 0.5022790729999542]
# [Generator loss: 0.2846390902996063, Discriminator loss: 0.5022572576999664]
# [Generator loss: 0.28455764055252075, Discriminator loss: 0.5022470355033875]
# [Generator loss: 0.2844761610031128, Discriminator loss: 0.5022370964288712]
# [Generator loss: 0.284394770860672, Discriminator loss: 0.5022266805171967]
# [Generator loss: 0.2843138575553894, Discriminator loss: 0.5022163093090057]
# [Generator loss: 0.2842326760292053, Discriminator loss: 0.5022232830524445]
# [Generator loss: 0.28415173292160034, Discriminator loss: 0.5022098273038864]
# [Generator loss: 0.2840709090232849, Discriminator loss: 0.5021866112947464]
# [Generator loss: 0.28399041295051575, Discriminator loss: 0.5021764039993286]
# [Generator loss: 0.28390973806381226, Discriminator loss: 0.502167671918869]
# [Generator loss: 0.2838292717933655, Discriminator loss: 0.5021591335535049]
# [Generator loss: 0.2837490439414978, Discriminator loss: 0.5021467357873917]
# [Generator loss: 0.2836688458919525, Discriminator loss: 0.5021449029445648]
# [Generator loss: 0.28358879685401917, Discriminator loss: 0.5021359622478485]
# [Generator loss: 0.28350985050201416, Discriminator loss: 0.5021158754825592]
# [Generator loss: 0.2834290862083435, Discriminator loss: 0.5021104216575623]
# [Generator loss: 0.2833491563796997, Discriminator loss: 0.5020974576473236]
# [Generator loss: 0.2832726836204529, Discriminator loss: 0.5020850896835327]
# [Generator loss: 0.28319036960601807, Discriminator loss: 0.5020793080329895]
# [Generator loss: 0.28311067819595337, Discriminator loss: 0.502073347568512]
# [Generator loss: 0.2830316126346588, Discriminator loss: 0.5020599067211151]
# [Generator loss: 0.2829526662826538, Discriminator loss: 0.5020490884780884]
# [Generator loss: 0.2828734219074249, Discriminator loss: 0.5020400583744049]
# [Generator loss: 0.2827945649623871, Discriminator loss: 0.5020336210727692]
# [Generator loss: 0.28271588683128357, Discriminator loss: 0.5020372867584229]
# [Generator loss: 0.28263697028160095, Discriminator loss: 0.502385824918747]
# [Generator loss: 0.2825583815574646, Discriminator loss: 0.5020043253898621]
# [Generator loss: 0.2824799418449402, Discriminator loss: 0.5019925534725189]
# [Generator loss: 0.2824016213417053, Discriminator loss: 0.5019831210374832]
# [Generator loss: 0.2823234796524048, Discriminator loss: 0.5019743293523788]
# [Generator loss: 0.2822456657886505, Discriminator loss: 0.5019643008708954]
# [Generator loss: 0.2821676731109619, Discriminator loss: 0.5019554495811462]
# [Generator loss: 0.2820906341075897, Discriminator loss: 0.5019511431455612]
# [Generator loss: 0.2820119261741638, Discriminator loss: 0.5019389241933823]
# [Generator loss: 0.28193455934524536, Discriminator loss: 0.5019283294677734]
# ...
# [Generator loss: 0.2522701025009155, Discriminator loss: 0.500012144446373]
# [Generator loss: 0.25226065516471863, Discriminator loss: 0.5000102818012238]
# [Generator loss: 0.25225117802619934, Discriminator loss: 0.5000102072954178]
# [Generator loss: 0.2522417902946472, Discriminator loss: 0.5000100880861282]
# [Generator loss: 0.2522323727607727, Discriminator loss: 0.5000123977661133]
# [Generator loss: 0.25222310423851013, Discriminator loss: 0.5000098794698715]
# [Generator loss: 0.25221383571624756, Discriminator loss: 0.5000098347663879]
# [Generator loss: 0.2522045969963074, Discriminator loss: 0.500009760260582]
# [Generator loss: 0.2521953880786896, Discriminator loss: 0.5000097006559372]
# [Generator loss: 0.2521861791610718, Discriminator loss: 0.5000096261501312]
# [Generator loss: 0.25217700004577637, Discriminator loss: 0.5000095218420029]
# [Generator loss: 0.25216785073280334, Discriminator loss: 0.5000094324350357]
# [Generator loss: 0.2521587610244751, Discriminator loss: 0.5000099539756775]
# [Generator loss: 0.25214970111846924, Discriminator loss: 0.5000092834234238]
# [Generator loss: 0.25214067101478577, Discriminator loss: 0.5000094324350357]
# [Generator loss: 0.25213170051574707, Discriminator loss: 0.500009149312973]
# [Generator loss: 0.2521227300167084, Discriminator loss: 0.5000091195106506]
# [Generator loss: 0.2521137297153473, Discriminator loss: 0.5000090152025223]
# [Generator loss: 0.25210487842559814, Discriminator loss: 0.5000088661909103]
# [Generator loss: 0.252096027135849, Discriminator loss: 0.5000088214874268]
# [Generator loss: 0.25208717584609985, Discriminator loss: 0.500008761882782]
# [Generator loss: 0.25207841396331787, Discriminator loss: 0.5000086575746536]
# [Generator loss: 0.2520696222782135, Discriminator loss: 0.5000090152025223]
# [Generator loss: 0.2520608901977539, Discriminator loss: 0.5000085234642029]
# [Generator loss: 0.2520522177219391, Discriminator loss: 0.5000084638595581]
# [Generator loss: 0.2520434856414795, Discriminator loss: 0.5000084191560745]
# [Generator loss: 0.25203484296798706, Discriminator loss: 0.500008299946785]
# [Generator loss: 0.252026230096817, Discriminator loss: 0.5000082403421402]
# [Generator loss: 0.252017617225647, Discriminator loss: 0.5000081658363342]
# [Generator loss: 0.2520091235637665, Discriminator loss: 0.5000080764293671]
# [Generator loss: 0.2520005702972412, Discriminator loss: 0.5000080764293671]
# [Generator loss: 0.2519920766353607, Discriminator loss: 0.5000079870223999]
# [Generator loss: 0.251983642578125, Discriminator loss: 0.5000079125165939]
# [Generator loss: 0.2519751191139221, Discriminator loss: 0.5000079125165939]
# [Generator loss: 0.2519667446613312, Discriminator loss: 0.5000077337026596]
# [Generator loss: 0.25195837020874023, Discriminator loss: 0.5000077039003372]
# [Generator loss: 0.2519499957561493, Discriminator loss: 0.5000076293945312]
# [Generator loss: 0.2519417405128479, Discriminator loss: 0.5000075697898865]
# [Generator loss: 0.25193342566490173, Discriminator loss: 0.5000075399875641]
# [Generator loss: 0.25192517042160034, Discriminator loss: 0.5000074803829193]
# [Generator loss: 0.2519169747829437, Discriminator loss: 0.5000075101852417]
# [Generator loss: 0.25190871953964233, Discriminator loss: 0.5000073909759521]
# [Generator loss: 0.2519005835056305, Discriminator loss: 0.5000072419643402]
# [Generator loss: 0.25189244747161865, Discriminator loss: 0.500007227063179]
# [Generator loss: 0.2518843114376068, Discriminator loss: 0.5000071674585342]
# [Generator loss: 0.2518762946128845, Discriminator loss: 0.5000070482492447]
# [Generator loss: 0.25186821818351746, Discriminator loss: 0.5000070482492447]
# [Generator loss: 0.25186020135879517, Discriminator loss: 0.5000069886445999]
# [Generator loss: 0.25185224413871765, Discriminator loss: 0.5000068992376328]
# [Generator loss: 0.25184422731399536, Discriminator loss: 0.5000068694353104]
# [Generator loss: 0.2518363296985626, Discriminator loss: 0.5000067502260208]
# [Generator loss: 0.2518284320831299, Discriminator loss: 0.5000067502260208]
# [Generator loss: 0.25182053446769714, Discriminator loss: 0.5000066757202148]
# [Generator loss: 0.25181275606155396, Discriminator loss: 0.5000065863132477]
# [Generator loss: 0.251804918050766, Discriminator loss: 0.5000066459178925]
# [Generator loss: 0.2517971396446228, Discriminator loss: 0.5000064969062805]
# [Generator loss: 0.2517894208431244, Discriminator loss: 0.5000064373016357]
# [Generator loss: 0.2517816424369812, Discriminator loss: 0.5000064074993134]
# [Generator loss: 0.25177398324012756, Discriminator loss: 0.5000062882900238]
# [Generator loss: 0.2517663240432739, Discriminator loss: 0.5000063478946686]
# [Generator loss: 0.2517586648464203, Discriminator loss: 0.5000062435865402]
# [Generator loss: 0.25175103545188904, Discriminator loss: 0.5000062137842178]
# [Generator loss: 0.2517434358596802, Discriminator loss: 0.5000061243772507]
# [Generator loss: 0.2517358362674713, Discriminator loss: 0.5000060647726059]
# [Generator loss: 0.2517282962799072, Discriminator loss: 0.5000060200691223]
# [Generator loss: 0.2517208158969879, Discriminator loss: 0.5000059306621552]
# [Generator loss: 0.2517133355140686, Discriminator loss: 0.5000059008598328]
# [Generator loss: 0.25170591473579407, Discriminator loss: 0.500005841255188]
# [Generator loss: 0.25169849395751953, Discriminator loss: 0.5000058859586716]
# [Generator loss: 0.2516911029815674, Discriminator loss: 0.500005766749382]
# [Generator loss: 0.2516837418079376, Discriminator loss: 0.5000060647726059]
# [Generator loss: 0.25167638063430786, Discriminator loss: 0.5000056624412537]
# [Generator loss: 0.2516690790653229, Discriminator loss: 0.5000055730342865]
# [Generator loss: 0.2516617774963379, Discriminator loss: 0.5000055432319641]
# [Generator loss: 0.2516545057296753, Discriminator loss: 0.5000054985284805]
# [Generator loss: 0.25164732336997986, Discriminator loss: 0.5000068694353104]
# [Generator loss: 0.25164008140563965, Discriminator loss: 0.5000054836273193]
# [Generator loss: 0.2516328990459442, Discriminator loss: 0.5000053644180298]
# [Generator loss: 0.25162577629089355, Discriminator loss: 0.500005304813385]
# [Generator loss: 0.2516186237335205, Discriminator loss: 0.5000052899122238]
# [Generator loss: 0.2516115605831146, Discriminator loss: 0.5000052005052567]
# [Generator loss: 0.25160449743270874, Discriminator loss: 0.5000052154064178]
# [Generator loss: 0.25159743428230286, Discriminator loss: 0.5000051558017731]
# [Generator loss: 0.25159040093421936, Discriminator loss: 0.5000051409006119]
# [Generator loss: 0.25158339738845825, Discriminator loss: 0.5000050812959671]
# [Generator loss: 0.25157639384269714, Discriminator loss: 0.5000050365924835]
# [Generator loss: 0.2515694499015808, Discriminator loss: 0.5000049471855164]
# [Generator loss: 0.25156259536743164, Discriminator loss: 0.5000048726797104]
# [Generator loss: 0.2515557110309601, Discriminator loss: 0.5000048726797104]
# [Generator loss: 0.2515488266944885, Discriminator loss: 0.5000048577785492]
# [Generator loss: 0.25154197216033936, Discriminator loss: 0.5000047981739044]
# [Generator loss: 0.2515351474285126, Discriminator loss: 0.5000047236680984]
# [Generator loss: 0.25152838230133057, Discriminator loss: 0.5000047087669373]
# [Generator loss: 0.25152161717414856, Discriminator loss: 0.5000046491622925]
# [Generator loss: 0.2515149414539337, Discriminator loss: 0.5000046342611313]
# [Generator loss: 0.2515082359313965, Discriminator loss: 0.5000046193599701]
# [Generator loss: 0.25150153040885925, Discriminator loss: 0.5000045597553253]
# [Generator loss: 0.2514948546886444, Discriminator loss: 0.5000045150518417]
# [Generator loss: 0.25148820877075195, Discriminator loss: 0.5000045001506805]
# [Generator loss: 0.2514815628528595, Discriminator loss: 0.5000044107437134]
# [Generator loss: 0.2514750063419342, Discriminator loss: 0.5000043660402298]
# [Generator loss: 0.2514684796333313, Discriminator loss: 0.5000043511390686]
# [Generator loss: 0.2514619827270508, Discriminator loss: 0.5000042915344238]
# [Generator loss: 0.2514553964138031, Discriminator loss: 0.500004306435585]
# [Generator loss: 0.25144892930984497, Discriminator loss: 0.5000042021274567]
# [Generator loss: 0.25144249200820923, Discriminator loss: 0.5000041723251343]
# [Generator loss: 0.2514360249042511, Discriminator loss: 0.5000041574239731]
# [Generator loss: 0.2514296770095825, Discriminator loss: 0.5000066161155701]
# [Generator loss: 0.2514232397079468, Discriminator loss: 0.5000040978193283]
# [Generator loss: 0.2514168918132782, Discriminator loss: 0.5000040233135223]
# [Generator loss: 0.251410573720932, Discriminator loss: 0.5000039935112]
# [Generator loss: 0.2514042258262634, Discriminator loss: 0.5000039786100388]
# [Generator loss: 0.2513979971408844, Discriminator loss: 0.5000039041042328]
# [Generator loss: 0.2513916790485382, Discriminator loss: 0.5000039488077164]
# [Generator loss: 0.2513854503631592, Discriminator loss: 0.500003844499588]
# [Generator loss: 0.25137925148010254, Discriminator loss: 0.5000038146972656]
# [Generator loss: 0.2513730227947235, Discriminator loss: 0.5000037997961044]
# [Generator loss: 0.2513669431209564, Discriminator loss: 0.5000037252902985]
# [Generator loss: 0.2513607144355774, Discriminator loss: 0.500003769993782]
# [Generator loss: 0.2513546049594879, Discriminator loss: 0.5000036656856537]
# [Generator loss: 0.2513485252857208, Discriminator loss: 0.5000036805868149]
# [Generator loss: 0.25134241580963135, Discriminator loss: 0.5000036656856537]
# [Generator loss: 0.2513364553451538, Discriminator loss: 0.5000035613775253]
# [Generator loss: 0.25133034586906433, Discriminator loss: 0.5000036060810089]
# [Generator loss: 0.2513243854045868, Discriminator loss: 0.5000035166740417]
# [Generator loss: 0.25131839513778687, Discriminator loss: 0.5000040680170059]
# [Generator loss: 0.2513124346733093, Discriminator loss: 0.500003457069397]
# [Generator loss: 0.2513065040111542, Discriminator loss: 0.5000034123659134]
# [Generator loss: 0.2513006031513214, Discriminator loss: 0.5000033974647522]
# [Generator loss: 0.25129473209381104, Discriminator loss: 0.500003382563591]
# [Generator loss: 0.25128889083862305, Discriminator loss: 0.5000033676624298]
# [Generator loss: 0.25128301978111267, Discriminator loss: 0.5000033527612686]
# [Generator loss: 0.2512771785259247, Discriminator loss: 0.5000032782554626]
# [Generator loss: 0.25127142667770386, Discriminator loss: 0.5000032633543015]
# [Generator loss: 0.25126564502716064, Discriminator loss: 0.5000032484531403]
# [Generator loss: 0.2512598931789398, Discriminator loss: 0.5000032037496567]
# [Generator loss: 0.2512541711330414, Discriminator loss: 0.5000031590461731]
# [Generator loss: 0.25124847888946533, Discriminator loss: 0.5000031739473343]
# [Generator loss: 0.2512427568435669, Discriminator loss: 0.5000032782554626]
# [Generator loss: 0.2512371242046356, Discriminator loss: 0.5000031143426895]
# [Generator loss: 0.25123152136802673, Discriminator loss: 0.5000031590461731]
# [Generator loss: 0.25122588872909546, Discriminator loss: 0.5000030994415283]
# [Generator loss: 0.2512202858924866, Discriminator loss: 0.5000030249357224]
# [Generator loss: 0.2512146532535553, Discriminator loss: 0.5000029802322388]
# [Generator loss: 0.25120916962623596, Discriminator loss: 0.5000029057264328]
# [Generator loss: 0.25120359659194946, Discriminator loss: 0.5000029504299164]
# [Generator loss: 0.2511981129646301, Discriminator loss: 0.5000028759241104]
# [Generator loss: 0.2511926293373108, Discriminator loss: 0.5000028610229492]
# [Generator loss: 0.25118717551231384, Discriminator loss: 0.500002846121788]
# [Generator loss: 0.2511816918849945, Discriminator loss: 0.5000028610229492]
# [Generator loss: 0.25117629766464233, Discriminator loss: 0.5000027865171432]
# [Generator loss: 0.25117093324661255, Discriminator loss: 0.5000027567148209]
# [Generator loss: 0.2511655390262604, Discriminator loss: 0.5000027716159821]
# [Generator loss: 0.2511601746082306, Discriminator loss: 0.5000027269124985]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\workspace\DCGAN\LSGAN_CelebA\LSGAN_CelebA\PCA_LSGAN_FFHQ.ipynb 셀 16 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/workspace/DCGAN/LSGAN_CelebA/LSGAN_CelebA/PCA_LSGAN_FFHQ.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> for e in range(1, epochs+1):
#       <a href='vscode-notebook-cell:/d%3A/workspace/DCGAN/LSGAN_CelebA/LSGAN_CelebA/PCA_LSGAN_FFHQ.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     print(f"Epoch {e} started.")
# ----> <a href='vscode-notebook-cell:/d%3A/workspace/DCGAN/LSGAN_CelebA/LSGAN_CelebA/PCA_LSGAN_FFHQ.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>     for i, batch in enumerate(dataloader, 1):
#       <a href='vscode-notebook-cell:/d%3A/workspace/DCGAN/LSGAN_CelebA/LSGAN_CelebA/PCA_LSGAN_FFHQ.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a>         batch_size = batch.size(0)
#       <a href='vscode-notebook-cell:/d%3A/workspace/DCGAN/LSGAN_CelebA/LSGAN_CelebA/PCA_LSGAN_FFHQ.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>         real_image = batch.to(device)
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torch\utils\data\dataloader.py:652, in _BaseDataLoaderIter.__next__(self)
#     649 if self._sampler_iter is None:
#     650     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651     self._reset()  # type: ignore[call-arg]
# --> 652 data = self._next_data()
#     653 self._num_yielded += 1
#     654 if self._dataset_kind == _DatasetKind.Iterable and \
#     655         self._IterableDataset_len_called is not None and \
#     656         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torch\utils\data\dataloader.py:692, in _SingleProcessDataLoaderIter._next_data(self)
#     690 def _next_data(self):
#     691     index = self._next_index()  # may raise StopIteration
# --> 692     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     693     if self._pin_memory:
#     694         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File d:\workspace\DCGAN\LSGAN_CelebA\LSGAN_CelebA\FFHQ.py:25, in FFHQ.__getitem__(self, idx)
#      21 image = Image.open(self.image_names[idx]).convert('RGB')
#      24 if self.transform:
# ---> 25     image = self.transform(image)
#      27 return image
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torchvision\transforms\transforms.py:94, in Compose.__call__(self, img)
#      92 def __call__(self, img):
#      93     for t in self.transforms:
# ---> 94         img = t(img)
#      95     return img
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torchvision\transforms\transforms.py:134, in ToTensor.__call__(self, pic)
#     126 def __call__(self, pic):
#     127     """
#     128     Args:
#     129         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     132         Tensor: Converted image.
#     133     """
# --> 134     return F.to_tensor(pic)
#
# File c:\Users\VIM_PC\anaconda3\envs\GAN\lib\site-packages\torchvision\transforms\functional.py:172, in to_tensor(pic)
#     170 img = img.permute((2, 0, 1)).contiguous()
#     171 if isinstance(img, torch.ByteTensor):
# --> 172     return img.to(dtype=default_float_dtype).div(255)
#     173 else:
#     174     return img
#
# KeyboardInterrupt:

# %%
plot_losses(g_losses,d_losses)

# %%
avg_Gloss = np.average(g_losses)
print("Average Generator Loss:", avg_Gloss)

avg_Dloss = np.average(d_losses)
print("Average Discriminator Loss:",avg_Dloss)
# Out:
# Average Generator Loss: 0.30371594544544167
# Average Discriminator Loss: 0.5029017349629223
